# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = arange(7)

# %%
a
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
plot(sinc(a))

# %%
import scipy.misc

# %%
image = imread('Penguins.jpg')

# %%
imshow(image)
